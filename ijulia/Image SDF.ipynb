# %%
using ImageIO
using Images
using SignedDistanceFields
using Plots
using Colors

# %%
img = load("julia-logo-color.png")
# Out:
# 200×320 Array{RGBA{N0f8},2} with eltype RGBA{Normed{UInt8,8}}:
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)  …  RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)  …  RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)  …  RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  ⋮                            ⋱
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)  …  RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)  …  RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)
#  RGBA{N0f8}(0.0,0.0,0.0,0.0)     RGBA{N0f8}(0.0,0.0,0.0,0.0)

# %%
boolimg = map(pix-> iszero(pix), img);
contour(Float32.(boolimg), levels=1, line_z = 0.5,linewidth=2)

# %%
Gray.(boolimg)
# Out:
# 200×320 Array{Gray{Bool},2} with eltype Gray{Bool}:
#  Gray{Bool}(true)  Gray{Bool}(true)  …  Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)  …  Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)  …  Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  ⋮                                   ⋱
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)  …  Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)  …  Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)
#  Gray{Bool}(true)  Gray{Bool}(true)     Gray{Bool}(true)  Gray{Bool}(true)

# %%
sdfimg = sdf(boolimg);
contour(sdfimg)

# %%
minv,maxv = extrema(sdfimg)
rng = maxv-minv
# Out:
# 83.68368041838224

# %%
map(v -> RGB(ntuple(_->(v-minv)/rng,3)...), sdfimg)
# Out:
# 200×320 Array{RGB{Float64},2} with eltype RGB{Float64}:
#  RGB{Float64}(0.0764566,0.0764566,0.0764566)  …  RGB{Float64}(0.0341603,0.0341603,0.0341603)
#  RGB{Float64}(0.0848554,0.0848554,0.0848554)     RGB{Float64}(0.0424655,0.0424655,0.0424655)
#  RGB{Float64}(0.0933561,0.0933561,0.0933561)     RGB{Float64}(0.0506704,0.0506704,0.0506704)
#  RGB{Float64}(0.101754,0.101754,0.101754)        RGB{Float64}(0.0587715,0.0587715,0.0587715)
#  RGB{Float64}(0.110044,0.110044,0.110044)        RGB{Float64}(0.0667653,0.0667653,0.0667653)
#  RGB{Float64}(0.118224,0.118224,0.118224)     …  RGB{Float64}(0.0746482,0.0746482,0.0746482)
#  RGB{Float64}(0.126289,0.126289,0.126289)        RGB{Float64}(0.0824165,0.0824165,0.0824165)
#  RGB{Float64}(0.134235,0.134235,0.134235)        RGB{Float64}(0.0900664,0.0900664,0.0900664)
#  RGB{Float64}(0.142056,0.142056,0.142056)        RGB{Float64}(0.0975939,0.0975939,0.0975939)
#  RGB{Float64}(0.14975,0.14975,0.14975)           RGB{Float64}(0.104995,0.104995,0.104995)
#  RGB{Float64}(0.157311,0.157311,0.157311)     …  RGB{Float64}(0.112265,0.112265,0.112265)
#  RGB{Float64}(0.164734,0.164734,0.164734)        RGB{Float64}(0.119401,0.119401,0.119401)
#  RGB{Float64}(0.172014,0.172014,0.172014)        RGB{Float64}(0.126397,0.126397,0.126397)
#  ⋮                                            ⋱
#  RGB{Float64}(0.678688,0.678688,0.678688)        RGB{Float64}(0.475542,0.475542,0.475542)
#  RGB{Float64}(0.678688,0.678688,0.678688)        RGB{Float64}(0.464479,0.464479,0.464479)
#  RGB{Float64}(0.678026,0.678026,0.678026)     …  RGB{Float64}(0.453354,0.453354,0.453354)
#  RGB{Float64}(0.676065,0.676065,0.676065)        RGB{Float64}(0.442174,0.442174,0.442174)
#  RGB{Float64}(0.672871,0.672871,0.672871)        RGB{Float64}(0.430944,0.430944,0.430944)
#  RGB{Float64}(0.668545,0.668545,0.668545)        RGB{Float64}(0.419669,0.419669,0.419669)
#  RGB{Float64}(0.664372,0.664372,0.664372)        RGB{Float64}(0.408352,0.408352,0.408352)
#  RGB{Float64}(0.661477,0.661477,0.661477)     …  RGB{Float64}(0.396997,0.396997,0.396997)
#  RGB{Float64}(0.657533,0.657533,0.657533)        RGB{Float64}(0.385607,0.385607,0.385607)
#  RGB{Float64}(0.652634,0.652634,0.652634)        RGB{Float64}(0.374186,0.374186,0.374186)
#  RGB{Float64}(0.646879,0.646879,0.646879)        RGB{Float64}(0.362736,0.362736,0.362736)
#  RGB{Float64}(0.640371,0.640371,0.640371)        RGB{Float64}(0.351258,0.351258,0.351258)
